# %% [markdown]
# # Installing the R kernel
#
# Installing the R kernel with SageMaker's hosted notebook environment is as simple as:

# %%
# !conda install --yes --name JupyterSystemEnv --channel r r-essentials=1.6.0
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/JupyterSystemEnv
#
#   added / updated specs:
#     - r-essentials=1.6.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     r-survival-2.41_3          |         r3.4.1_0         5.1 MB  r
#     r-glue-1.1.1               |         r3.4.1_0          33 KB  r
#     r-httpuv-1.3.3             |         r3.4.1_0         370 KB  r
#     pango-1.40.3               |                1         938 KB
#     ncurses-5.9                |               10         904 KB
#     r-mime-0.5                 |         r3.4.1_0          30 KB  r
#     r-maps-3.2.0               |         r3.4.1_0         3.4 MB  r
#     r-evaluate-0.10            |         r3.4.1_0          51 KB  r
#     r-foreign-0.8_68           |         r3.4.1_0         243 KB  r
#     r-jsonlite-1.5             |         r3.4.1_0         1.0 MB  r
#     r-dbi-0.6_1                |         r3.4.1_0         734 KB  r
#     graphviz-2.38.0            |                5        12.0 MB
#     r-psych-1.7.5              |         r3.4.1_0         3.8 MB  r
#     r-yaml-2.1.14              |         r3.4.1_0          85 KB  r
#     r-lubridate-1.6.0          |         r3.4.1_0         690 KB  r
#     r-formatr-1.5              |         r3.4.1_0         127 KB  r
#     r-stringi-1.1.5            |         r3.4.1_0         694 KB  r
#     r-xtable-1.8_2             |         r3.4.1_0         694 KB  r
#     r-matrixmodels-0.4_1       |         r3.4.1_0         238 KB  r
#     icu-54.1                   |                0        11.3 MB
#     r-mnormt-1.5_5             |         r3.4.1_0          68 KB  r
#     r-boot-1.3_19              |         r3.4.1_0         625 KB  r
#     r-nlme-3.1_131             |         r3.4.1_0         2.2 MB  r
#     r-lme4-1.1_13              |         r3.4.1_0         4.5 MB  r
#     r-rcpp-0.12.11             |         r3.4.1_0         2.4 MB  r
#     gsl-2.4                    |       h14c3975_4         2.6 MB
#     r-assertthat-0.2.0         |         r3.4.1_0          47 KB  r
#     r-nnet-7.3_12              |         r3.4.1_0         117 KB  r
#     libxslt-1.1.29             |                0         983 KB
#     libxml2-2.9.4              |                0         3.7 MB
#     r-modelmetrics-1.1.0       |         r3.4.1_0         114 KB  r
#     r-nloptr-1.0.4             |         r3.4.1_2         961 KB  r
#     libpq-9.6.6                |       h4e02ad2_0         101 KB
#     r-selectr-0.3_1            |         r3.4.1_0         181 KB  r
#     r-class-7.3_14             |         r3.4.1_0          92 KB  r
#     pcre-8.39                  |                1         656 KB
#     r-rcolorbrewer-1.1_2       |         r3.4.1_3          30 KB  r
#     r-quantmod-0.4_9           |         r3.4.1_0         503 KB  r
#     fontconfig-2.12.1          |                3         429 KB
#     r-lattice-0.20_35          |         r3.4.1_0         716 KB  r
#     r-plogr-0.1_1              |         r3.4.1_0          17 KB  r
#     psycopg2-2.7.4             |   py36hb7f436b_0         292 KB
#     r-hms-0.3                  |         r3.4.1_0          24 KB  r
#     freetype-2.5.5             |                2         2.5 MB
#     r-tibble-1.3.3             |         r3.4.1_0         203 KB  r
#     r-rmarkdown-1.5            |         r3.4.1_0         1.8 MB  r
#     r-colorspace-1.3_2         |         r3.4.1_0         428 KB  r
#     r-digest-0.6.12            |         r3.4.1_0         120 KB  r
#     r-xml2-1.1.1               |         r3.4.1_0         282 KB  r
#     r-labeling-0.3             |         r3.4.1_2          44 KB  r
#     r-spatial-7.3_11           |         r3.4.1_0         138 KB  r
#     r-kernsmooth-2.23_15       |         r3.4.1_0          97 KB  r
#     r-markdown-0.8             |         r3.4.1_0         111 KB  r
#     r-foreach-1.4.3            |         r3.4.1_0         374 KB  r
#     tk-8.5.18                  |                0         1.9 MB
#     r-catools-1.17.1           |         r3.4.1_2         162 KB  r
#     r-zoo-1.8_0                |         r3.4.1_0         870 KB  r
#     r-httr-1.2.1               |         r3.4.1_0         272 KB  r
#     r-quantreg-5.33            |         r3.4.1_0         1.7 MB  r
#     r-forcats-0.2.0            |         r3.4.1_0         167 KB  r
#     r-car-2.1_4                |         r3.4.1_0         1.6 MB  r
#     r-rprojroot-1.2            |         r3.4.1_0          60 KB  r
#     r-recommended-3.4.1        |         r3.4.1_0           2 KB  r
#     r-cluster-2.0.6            |         r3.4.1_0         513 KB  r
#     gstreamer-1.8.0            |                0         2.6 MB
#     libiconv-1.14              |                0         2.0 MB
#     r-irdisplay-0.4.4          |         r3.4.1_0          27 KB  r
#     r-pbkrtest-0.4_7           |         r3.4.1_0         200 KB  r
#     glib-2.50.2                |                1         5.6 MB
#     r-repr-0.10                |         r3.4.1_0          64 KB  r
#     lxml-4.1.1                 |   py36h4d89739_0         1.5 MB
#     r-uuid-0.1_2               |         r3.4.1_0          21 KB  r
#     r-xts-0.9_7                |         r3.4.1_2         612 KB  r
#     r-rpart-4.1_11             |         r3.4.1_0         899 KB  r
#     r-scales-0.4.1             |         r3.4.1_0         245 KB  r
#     sqlite-3.13.0              |                0         4.0 MB
#     r-pryr-0.1.2               |         r3.4.1_0         213 KB  r
#     r-curl-2.6                 |         r3.4.1_0         407 KB  r
#     r-backports-1.1.0          |         r3.4.1_0          36 KB  r
#     pillow-4.2.1               |           py36_0         870 KB
#     r-caret-6.0_76             |         r3.4.1_0         2.7 MB  r
#     r-lazyeval-0.2.0           |         r3.4.1_0         122 KB  r
#     r-munsell-0.4.3            |         r3.4.1_0         135 KB  r
#     matplotlib-2.0.2           |      np113py36_0        10.9 MB
#     _r-mutex-1.0.0             |      anacondar_1           2 KB  r
#     cairo-1.14.8               |                0         609 KB
#     dbus-1.10.20               |                0         1.4 MB
#     r-mass-7.3_47              |         r3.4.1_0         1.1 MB  r
#     r-irkernel-0.7.1           |         r3.4.1_0         127 KB  r
#     r-sourcetools-0.1.6        |         r3.4.1_0          66 KB  r
#     r-dplyr-0.7.0              |         r3.4.1_0         1.8 MB  r
#     r-dichromat-2.0_0          |         r3.4.1_2         150 KB  r
#     r-htmlwidgets-0.8          |         r3.4.1_1         743 KB  r
#     r-rbokeh-0.5.0             |         r3.4.1_0         1.2 MB  r
#     r-rcppeigen-0.3.3.3.0      |         r3.4.1_0         2.2 MB  r
#     r-base64enc-0.1_3          |         r3.4.1_0          29 KB  r
#     r-shiny-1.0.3              |         r3.4.1_0         2.4 MB  r
#     r-gtable-0.2.0             |         r3.4.1_0          62 KB  r
#     r-ggplot2-2.2.1            |         r3.4.1_0         2.7 MB  r
#     krb5-1.14.2                |       h56d4222_4         1.4 MB
#     r-sparsem-1.77             |         r3.4.1_0         934 KB  r
#     r-matrix-1.2_10            |         r3.4.1_0         2.4 MB  r
#     r-gistr-0.4.0              |         r3.4.1_0         1.7 MB  r
#     r-crayon-1.3.2             |         r3.4.1_0         702 KB  r
#     r-r6-2.2.1                 |         r3.4.1_0         259 KB  r
#     r-readxl-1.0.0             |         r3.4.1_0         855 KB  r
#     readline-6.2               |                2         606 KB
#     r-bindrcpp-0.2             |         r3.4.1_0         108 KB  r
#     numpy-1.13.3               |   py36hdbf6ddf_4         3.9 MB
#     libgcc-7.2.0               |       h69d50b8_2         304 KB
#     gst-plugins-base-1.8.0     |                0         3.1 MB
#     r-reshape2-1.4.2           |         r3.4.1_0         117 KB  r
#     r-modelr-0.1.0             |         r3.4.1_0         133 KB  r
#     r-plyr-1.8.4               |         r3.4.1_0         761 KB  r
#     r-iterators-1.0.8          |         r3.4.1_0         314 KB  r
#     harfbuzz-0.9.39            |                2         1.2 MB
#     notebook-5.4.1             |           py36_0         6.6 MB
#     r-rvest-0.3.2              |         r3.4.1_0         841 KB  r
#     r-mgcv-1.8_17              |         r3.4.1_0         2.3 MB  r
#     r-randomforest-4.6_12      |         r3.4.1_0         146 KB  r
#     r-glmnet-2.0_10            |         r3.4.1_0         1.3 MB  r
#     r-essentials-1.6.0         |         r3.4.1_0           4 KB  r
#     qt-5.6.2                   |                5        43.5 MB
#     r-base-3.4.1               |                1        23.5 MB  r
#     r-magrittr-1.5             |         r3.4.1_2         165 KB  r
#     r-codetools-0.2_15         |         r3.4.1_0          49 KB  r
#     r-hexbin-1.27.1            |         r3.4.1_0         756 KB  r
#     r-bitops-1.0_6             |         r3.4.1_2          27 KB  r
#     r-readr-1.1.1              |         r3.4.1_0         626 KB  r
#     python-3.6.2               |                0        16.5 MB
#     r-stringr-1.2.0            |         r3.4.1_0         141 KB  r
#     r-pbdzmq-0.2_6             |         r3.4.1_0         361 KB  r
#     r-bindr-0.1                |         r3.4.1_0          17 KB  r
#     r-tidyr-0.6.3              |         r3.4.1_0         392 KB  r
#     r-purrr-0.2.2.2            |         r3.4.1_0         170 KB  r
#     zeromq-4.1.5               |                0         4.1 MB
#     r-minqa-1.2.4              |         r3.4.1_2         119 KB  r
#     r-cellranger-1.1.0         |         r3.4.1_0          78 KB  r
#     r-knitr-1.16               |         r3.4.1_0         868 KB  r
#     r-htmltools-0.3.6          |         r3.4.1_0         145 KB  r
#     r-ttr-0.23_1               |         r3.4.1_0         421 KB  r
#     r-tidyverse-1.1.1          |         r3.4.1_0          41 KB  r
#     r-rlang-0.1.1              |         r3.4.1_0         444 KB  r
#     r-pkgconfig-2.0.1          |         r3.4.1_0          21 KB  r
#     r-highr-0.6                |         r3.4.1_0          34 KB  r
#     pyzmq-16.0.2               |           py36_0         921 KB
#     r-broom-0.4.2              |         r3.4.1_0         1.6 MB  r
#     r-openssl-0.9.6            |         r3.4.1_0         1.2 MB  r
#     r-rematch-1.0.1            |         r3.4.1_0          16 KB  r
#     r-data.table-1.10.4        |         r3.4.1_0         1.2 MB  r
#     r-haven-1.0.0              |         r3.4.1_0         260 KB  r
#     r-bh-1.62.0_1              |         r3.4.1_0         9.0 MB  r
#     ------------------------------------------------------------
#                                            Total:       260.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     _r-mutex:         1.0.0-anacondar_1       r
#     gsl:              2.4-h14c3975_4
#     libgcc:           7.2.0-h69d50b8_2
#     libiconv:         1.14-0
#     r-assertthat:     0.2.0-r3.4.1_0          r
#     r-backports:      1.1.0-r3.4.1_0          r
#     r-base:           3.4.1-1                 r
#     r-base64enc:      0.1_3-r3.4.1_0          r
#     r-bh:             1.62.0_1-r3.4.1_0       r
#     r-bindr:          0.1-r3.4.1_0            r
#     r-bindrcpp:       0.2-r3.4.1_0            r
#     r-bitops:         1.0_6-r3.4.1_2          r
#     r-boot:           1.3_19-r3.4.1_0         r
#     r-broom:          0.4.2-r3.4.1_0          r
#     r-car:            2.1_4-r3.4.1_0          r
#     r-caret:          6.0_76-r3.4.1_0         r
#     r-catools:        1.17.1-r3.4.1_2         r
#     r-cellranger:     1.1.0-r3.4.1_0          r
#     r-class:          7.3_14-r3.4.1_0         r
#     r-cluster:        2.0.6-r3.4.1_0          r
#     r-codetools:      0.2_15-r3.4.1_0         r
#     r-colorspace:     1.3_2-r3.4.1_0          r
#     r-crayon:         1.3.2-r3.4.1_0          r
#     r-curl:           2.6-r3.4.1_0            r
#     r-data.table:     1.10.4-r3.4.1_0         r
#     r-dbi:            0.6_1-r3.4.1_0          r
#     r-dichromat:      2.0_0-r3.4.1_2          r
#     r-digest:         0.6.12-r3.4.1_0         r
#     r-dplyr:          0.7.0-r3.4.1_0          r
#     r-essentials:     1.6.0-r3.4.1_0          r
#     r-evaluate:       0.10-r3.4.1_0           r
#     r-forcats:        0.2.0-r3.4.1_0          r
#     r-foreach:        1.4.3-r3.4.1_0          r
#     r-foreign:        0.8_68-r3.4.1_0         r
#     r-formatr:        1.5-r3.4.1_0            r
#     r-ggplot2:        2.2.1-r3.4.1_0          r
#     r-gistr:          0.4.0-r3.4.1_0          r
#     r-glmnet:         2.0_10-r3.4.1_0         r
#     r-glue:           1.1.1-r3.4.1_0          r
#     r-gtable:         0.2.0-r3.4.1_0          r
#     r-haven:          1.0.0-r3.4.1_0          r
#     r-hexbin:         1.27.1-r3.4.1_0         r
#     r-highr:          0.6-r3.4.1_0            r
#     r-hms:            0.3-r3.4.1_0            r
#     r-htmltools:      0.3.6-r3.4.1_0          r
#     r-htmlwidgets:    0.8-r3.4.1_1            r
#     r-httpuv:         1.3.3-r3.4.1_0          r
#     r-httr:           1.2.1-r3.4.1_0          r
#     r-irdisplay:      0.4.4-r3.4.1_0          r
#     r-irkernel:       0.7.1-r3.4.1_0          r
#     r-iterators:      1.0.8-r3.4.1_0          r
#     r-jsonlite:       1.5-r3.4.1_0            r
#     r-kernsmooth:     2.23_15-r3.4.1_0        r
#     r-knitr:          1.16-r3.4.1_0           r
#     r-labeling:       0.3-r3.4.1_2            r
#     r-lattice:        0.20_35-r3.4.1_0        r
#     r-lazyeval:       0.2.0-r3.4.1_0          r
#     r-lme4:           1.1_13-r3.4.1_0         r
#     r-lubridate:      1.6.0-r3.4.1_0          r
#     r-magrittr:       1.5-r3.4.1_2            r
#     r-maps:           3.2.0-r3.4.1_0          r
#     r-markdown:       0.8-r3.4.1_0            r
#     r-mass:           7.3_47-r3.4.1_0         r
#     r-matrix:         1.2_10-r3.4.1_0         r
#     r-matrixmodels:   0.4_1-r3.4.1_0          r
#     r-mgcv:           1.8_17-r3.4.1_0         r
#     r-mime:           0.5-r3.4.1_0            r
#     r-minqa:          1.2.4-r3.4.1_2          r
#     r-mnormt:         1.5_5-r3.4.1_0          r
#     r-modelmetrics:   1.1.0-r3.4.1_0          r
#     r-modelr:         0.1.0-r3.4.1_0          r
#     r-munsell:        0.4.3-r3.4.1_0          r
#     r-nlme:           3.1_131-r3.4.1_0        r
#     r-nloptr:         1.0.4-r3.4.1_2          r
#     r-nnet:           7.3_12-r3.4.1_0         r
#     r-openssl:        0.9.6-r3.4.1_0          r
#     r-pbdzmq:         0.2_6-r3.4.1_0          r
#     r-pbkrtest:       0.4_7-r3.4.1_0          r
#     r-pkgconfig:      2.0.1-r3.4.1_0          r
#     r-plogr:          0.1_1-r3.4.1_0          r
#     r-plyr:           1.8.4-r3.4.1_0          r
#     r-pryr:           0.1.2-r3.4.1_0          r
#     r-psych:          1.7.5-r3.4.1_0          r
#     r-purrr:          0.2.2.2-r3.4.1_0        r
#     r-quantmod:       0.4_9-r3.4.1_0          r
#     r-quantreg:       5.33-r3.4.1_0           r
#     r-r6:             2.2.1-r3.4.1_0          r
#     r-randomforest:   4.6_12-r3.4.1_0         r
#     r-rbokeh:         0.5.0-r3.4.1_0          r
#     r-rcolorbrewer:   1.1_2-r3.4.1_3          r
#     r-rcpp:           0.12.11-r3.4.1_0        r
#     r-rcppeigen:      0.3.3.3.0-r3.4.1_0      r
#     r-readr:          1.1.1-r3.4.1_0          r
#     r-readxl:         1.0.0-r3.4.1_0          r
#     r-recommended:    3.4.1-r3.4.1_0          r
#     r-rematch:        1.0.1-r3.4.1_0          r
#     r-repr:           0.10-r3.4.1_0           r
#     r-reshape2:       1.4.2-r3.4.1_0          r
#     r-rlang:          0.1.1-r3.4.1_0          r
#     r-rmarkdown:      1.5-r3.4.1_0            r
#     r-rpart:          4.1_11-r3.4.1_0         r
#     r-rprojroot:      1.2-r3.4.1_0            r
#     r-rvest:          0.3.2-r3.4.1_0          r
#     r-scales:         0.4.1-r3.4.1_0          r
#     r-selectr:        0.3_1-r3.4.1_0          r
#     r-shiny:          1.0.3-r3.4.1_0          r
#     r-sourcetools:    0.1.6-r3.4.1_0          r
#     r-sparsem:        1.77-r3.4.1_0           r
#     r-spatial:        7.3_11-r3.4.1_0         r
#     r-stringi:        1.1.5-r3.4.1_0          r
#     r-stringr:        1.2.0-r3.4.1_0          r
#     r-survival:       2.41_3-r3.4.1_0         r
#     r-tibble:         1.3.3-r3.4.1_0          r
#     r-tidyr:          0.6.3-r3.4.1_0          r
#     r-tidyverse:      1.1.1-r3.4.1_0          r
#     r-ttr:            0.23_1-r3.4.1_0         r
#     r-uuid:           0.1_2-r3.4.1_0          r
#     r-xml2:           1.1.1-r3.4.1_0          r
#     r-xtable:         1.8_2-r3.4.1_0          r
#     r-xts:            0.9_7-r3.4.1_2          r
#     r-yaml:           2.1.14-r3.4.1_0         r
#     r-zoo:            1.8_0-r3.4.1_0          r
#
# The following packages will be REMOVED:
#
#     libedit:          3.1.20170329-h6b74fdf_2
#
# The following packages will be UPDATED:
#
#     certifi:          2018.8.13-py36_0          --> 2018.8.24-py36_1
#
# The following packages will be DOWNGRADED:
#
#     cairo:            1.14.12-h8948797_3        --> 1.14.8-0
#     dbus:             1.13.2-h714fa37_1         --> 1.10.20-0
#     fontconfig:       2.13.0-h9420a91_0         --> 2.12.1-3
#     freetype:         2.9.1-h8a8886c_0          --> 2.5.5-2
#     glib:             2.56.1-h000015b_0         --> 2.50.2-1
#     graphviz:         2.40.1-h21bd128_2         --> 2.38.0-5
#     gst-plugins-base: 1.14.0-hbbd80ab_1         --> 1.8.0-0
#     gstreamer:        1.14.0-hb453b48_1         --> 1.8.0-0
#     harfbuzz:         1.8.4-hec2c2bc_0          --> 0.9.39-2
#     icu:              58.2-h9c2bf20_1           --> 54.1-0
#     krb5:             1.16.1-hc83ff2d_6         --> 1.14.2-h56d4222_4
#     libpq:            10.4-h1ad7b7a_0           --> 9.6.6-h4e02ad2_0
#     libxml2:          2.9.8-h26e45fe_1          --> 2.9.4-0
#     libxslt:          1.1.32-h1312cb7_0         --> 1.1.29-0
#     lxml:             4.2.1-py36h23eabaa_0      --> 4.1.1-py36h4d89739_0
#     matplotlib:       2.2.3-py36hb69df0a_0      --> 2.0.2-np113py36_0
#     ncurses:          6.1-hf484d3e_0            --> 5.9-10
#     notebook:         5.5.0-py36_0              --> 5.4.1-py36_0
#     numpy:            1.14.3-py36hcd700cb_1     --> 1.13.3-py36hdbf6ddf_4
#     pango:            1.42.3-h8589676_0         --> 1.40.3-1
#     pcre:             8.42-h439df22_0           --> 8.39-1
#     pillow:           5.2.0-py36heded4f4_0      --> 4.2.1-py36_0
#     psycopg2:         2.7.5-py36hb7f436b_0      --> 2.7.4-py36hb7f436b_0
#     pyqt:             5.9.2-py36h751905a_0      --> 5.6.0-py36_2
#     python:           3.6.5-hc3d631a_2          --> 3.6.2-0
#     pyzmq:            17.0.0-py36h14c3975_0     --> 16.0.2-py36_0
#     qt:               5.9.6-h52aff34_0          --> 5.6.2-5
#     readline:         7.0-ha6073c6_4            --> 6.2-2
#     sqlite:           3.23.1-he433501_0         --> 3.13.0-0
#     tk:               8.6.7-hc745277_3          --> 8.5.18-0
#     zeromq:           4.2.5-h439df22_0          --> 4.1.5-0
# Downloading and Extracting Packages
# r-survival 2.41_3: ##################################################### | 100%
# r-glue 1.1.1: ########################################################## | 100%
# r-httpuv 1.3.3: ######################################################## | 100%
# pango 1.40.3: ########################################################## | 100%
# ncurses 5.9: ########################################################### | 100%
# r-mime 0.5: ############################################################ | 100%
# r-maps 3.2.0: ########################################################## | 100%
# r-evaluate 0.10: ####################################################### | 100%
# r-foreign 0.8_68: ###################################################### | 100%
# r-jsonlite 1.5: ######################################################## | 100%
# r-dbi 0.6_1: ########################################################### | 100%
# graphviz 2.38.0: ####################################################### | 100%
# r-psych 1.7.5: ######################################################### | 100%
# r-yaml 2.1.14: ######################################################### | 100%
# r-lubridate 1.6.0: ##################################################### | 100%
# r-formatr 1.5: ######################################################### | 100%
# r-stringi 1.1.5: ####################################################### | 100%
# r-xtable 1.8_2: ######################################################## | 100%
# r-matrixmodels 0.4_1: ################################################## | 100%
# icu 54.1: ############################################################## | 100%
# r-mnormt 1.5_5: ######################################################## | 100%
# r-boot 1.3_19: ######################################################### | 100%
# r-nlme 3.1_131: ######################################################## | 100%
# r-lme4 1.1_13: ######################################################### | 100%
# r-rcpp 0.12.11: ######################################################## | 100%
# gsl 2.4: ############################################################### | 100%
# r-assertthat 0.2.0: #################################################### | 100%
# r-nnet 7.3_12: ######################################################### | 100%
# libxslt 1.1.29: ######################################################## | 100%
# libxml2 2.9.4: ######################################################### | 100%
# r-modelmetrics 1.1.0: ################################################## | 100%
# r-nloptr 1.0.4: ######################################################## | 100%
# libpq 9.6.6: ########################################################### | 100%
# r-selectr 0.3_1: ####################################################### | 100%
# r-class 7.3_14: ######################################################## | 100%
# pcre 8.39: ############################################################# | 100%
# r-rcolorbrewer 1.1_2: ################################################## | 100%
# r-quantmod 0.4_9: ###################################################### | 100%
# fontconfig 2.12.1: ##################################################### | 100%
# r-lattice 0.20_35: ##################################################### | 100%
# r-plogr 0.1_1: ######################################################### | 100%
# psycopg2 2.7.4: ######################################################## | 100%
# r-hms 0.3: ############################################################# | 100%
# freetype 2.5.5: ######################################################## | 100%
# r-tibble 1.3.3: ######################################################## | 100%
# r-rmarkdown 1.5: ####################################################### | 100%
# r-colorspace 1.3_2: #################################################### | 100%
# r-digest 0.6.12: ####################################################### | 100%
# r-xml2 1.1.1: ########################################################## | 100%
# r-labeling 0.3: ######################################################## | 100%
# r-spatial 7.3_11: ###################################################### | 100%
# r-kernsmooth 2.23_15: ################################################## | 100%
# r-markdown 0.8: ######################################################## | 100%
# r-foreach 1.4.3: ####################################################### | 100%
# tk 8.5.18: ############################################################# | 100%
# r-catools 1.17.1: ###################################################### | 100%
# r-zoo 1.8_0: ########################################################### | 100%
# r-httr 1.2.1: ########################################################## | 100%
# r-quantreg 5.33: ####################################################### | 100%
# r-forcats 0.2.0: ####################################################### | 100%
# r-car 2.1_4: ########################################################### | 100%
# r-rprojroot 1.2: ####################################################### | 100%
# r-recommended 3.4.1: ################################################### | 100%
# r-cluster 2.0.6: ####################################################### | 100%
# gstreamer 1.8.0: ####################################################### | 100%
# libiconv 1.14: ######################################################### | 100%
# r-irdisplay 0.4.4: ##################################################### | 100%
# r-pbkrtest 0.4_7: ###################################################### | 100%
# glib 2.50.2: ########################################################### | 100%
# r-repr 0.10: ########################################################### | 100%
# lxml 4.1.1: ############################################################ | 100%
# r-uuid 0.1_2: ########################################################## | 100%
# r-xts 0.9_7: ########################################################### | 100%
# r-rpart 4.1_11: ######################################################## | 100%
# r-scales 0.4.1: ######################################################## | 100%
# sqlite 3.13.0: ######################################################### | 100%
# r-pryr 0.1.2: ########################################################## | 100%
# r-curl 2.6: ############################################################ | 100%
# r-backports 1.1.0: ##################################################### | 100%
# pillow 4.2.1: ########################################################## | 100%
# r-caret 6.0_76: ######################################################## | 100%
# r-lazyeval 0.2.0: ###################################################### | 100%
# r-munsell 0.4.3: ####################################################### | 100%
# matplotlib 2.0.2: ###################################################### | 100%
# _r-mutex 1.0.0: ######################################################## | 100%
# cairo 1.14.8: ########################################################## | 100%
# dbus 1.10.20: ########################################################## | 100%
# r-mass 7.3_47: ######################################################### | 100%
# r-irkernel 0.7.1: ###################################################### | 100%
# r-sourcetools 0.1.6: ################################################### | 100%
# r-dplyr 0.7.0: ######################################################### | 100%
# r-dichromat 2.0_0: ##################################################### | 100%
# r-htmlwidgets 0.8: ##################################################### | 100%
# r-rbokeh 0.5.0: ######################################################## | 100%
# r-rcppeigen 0.3.3.3.0: ################################################# | 100%
# r-base64enc 0.1_3: ##################################################### | 100%
# r-shiny 1.0.3: ######################################################### | 100%
# r-gtable 0.2.0: ######################################################## | 100%
# r-ggplot2 2.2.1: ####################################################### | 100%
# krb5 1.14.2: ########################################################### | 100%
# r-sparsem 1.77: ######################################################## | 100%
# r-matrix 1.2_10: ####################################################### | 100%
# r-gistr 0.4.0: ######################################################### | 100%
# r-crayon 1.3.2: ######################################################## | 100%
# r-r6 2.2.1: ############################################################ | 100%
# r-readxl 1.0.0: ######################################################## | 100%
# readline 6.2: ########################################################## | 100%
# r-bindrcpp 0.2: ######################################################## | 100%
# numpy 1.13.3: ########################################################## | 100%
# libgcc 7.2.0: ########################################################## | 100%
# gst-plugins-base 1.8.0: ################################################ | 100%
# r-reshape2 1.4.2: ###################################################### | 100%
# r-modelr 0.1.0: ######################################################## | 100%
# r-plyr 1.8.4: ########################################################## | 100%
# r-iterators 1.0.8: ##################################################### | 100%
# harfbuzz 0.9.39: ####################################################### | 100%
# notebook 5.4.1: ######################################################## | 100%
# r-rvest 0.3.2: ######################################################### | 100%
# r-mgcv 1.8_17: ######################################################### | 100%
# r-randomforest 4.6_12: ################################################# | 100%
# r-glmnet 2.0_10: ####################################################### | 100%
# r-essentials 1.6.0: #################################################### | 100%
# qt 5.6.2: ############################################################## | 100%
# r-base 3.4.1: ########################################################## | 100%
# r-magrittr 1.5: ######################################################## | 100%
# r-codetools 0.2_15: #################################################### | 100%
# r-hexbin 1.27.1: ####################################################### | 100%
# r-bitops 1.0_6: ######################################################## | 100%
# r-readr 1.1.1: ######################################################### | 100%
# python 3.6.2: ########################################################## | 100%
# r-stringr 1.2.0: ####################################################### | 100%
# r-pbdzmq 0.2_6: ######################################################## | 100%
# r-bindr 0.1: ########################################################### | 100%
# r-tidyr 0.6.3: ######################################################### | 100%
# r-purrr 0.2.2.2: ####################################################### | 100%
# zeromq 4.1.5: ########################################################## | 100%
# r-minqa 1.2.4: ######################################################### | 100%
# r-cellranger 1.1.0: #################################################### | 100%
# r-knitr 1.16: ########################################################## | 100%
# r-htmltools 0.3.6: ##################################################### | 100%
# r-ttr 0.23_1: ########################################################## | 100%
# r-tidyverse 1.1.1: ##################################################### | 100%
# r-rlang 0.1.1: ######################################################### | 100%
# r-pkgconfig 2.0.1: ##################################################### | 100%
# r-highr 0.6: ########################################################### | 100%
# pyzmq 16.0.2: ########################################################## | 100%
# r-broom 0.4.2: ######################################################### | 100%
# r-openssl 0.9.6: ####################################################### | 100%
# r-rematch 1.0.1: ####################################################### | 100%
# r-data.table 1.10.4: ################################################### | 100%
# r-haven 1.0.0: ######################################################### | 100%
# r-bh 1.62.0_1: ######################################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: / dbus post-link :: /etc/machine-id not found ..
# dbus post-link :: .. using /proc/sys/kernel/random/boot_id
#
# done

# %% [markdown]
# wefiuhweihwef
# weiwuihf

# %% [markdown]
# Now just refresh your Jupyter dashboard, and select "R" from the "New" notebook drop-down.

# %%
# !ls
# Out:
# example_r_notebook.ipynb  install_r_kernel.ipynb  README.md

# %%
# !aws s3 cp
